# %%
# %pip install mlflow
# %pip install sklearn
# Out:
# Python interpreter will be restarted.
# Collecting mlflow
#   Using cached mlflow-2.19.0-py3-none-any.whl (27.4 MB)
# Collecting sqlalchemy<3,>=1.4.0
#   Using cached SQLAlchemy-2.0.37-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
# Collecting graphene<4
#   Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (1.7.3)
# Collecting docker<8,>=4.0.0
#   Using cached docker-7.1.0-py3-none-any.whl (147 kB)
# Requirement already satisfied: numpy<3 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (1.21.5)
# Collecting Flask<4
#   Using cached flask-3.1.0-py3-none-any.whl (102 kB)
# Collecting mlflow-skinny==2.19.0
#   Using cached mlflow_skinny-2.19.0-py3-none-any.whl (5.9 MB)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (7.0.0)
# Collecting gunicorn<24
#   Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Collecting markdown<4,>=3.3
#   Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Requirement already satisfied: pandas<3 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (1.4.2)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (1.0.2)
# Collecting alembic!=1.10.0,<2
#   Using cached alembic-1.14.0-py3-none-any.whl (233 kB)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (3.5.1)
# Requirement already satisfied: Jinja2<4,>=2.11 in /databricks/python3/lib/python3.9/site-packages (from mlflow) (2.11.3)
# Collecting sqlparse<1,>=0.4.0
#   Using cached sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Requirement already satisfied: requests<3,>=2.17.3 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny==2.19.0->mlflow) (2.27.1)
# Collecting opentelemetry-api<3,>=1.9.0
#   Using cached opentelemetry_api-1.29.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: click<9,>=7.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny==2.19.0->mlflow) (8.0.4)
# Collecting opentelemetry-sdk<3,>=1.9.0
#   Using cached opentelemetry_sdk-1.29.0-py3-none-any.whl (118 kB)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny==2.19.0->mlflow) (3.19.4)
# Collecting cloudpickle<4
#   Using cached cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Collecting pyyaml<7,>=5.1
#   Using cached PyYAML-6.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (737 kB)
# Collecting gitpython<4,>=3.1.9
#   Using cached GitPython-3.1.44-py3-none-any.whl (207 kB)
# Collecting cachetools<6,>=5.0.0
#   Using cached cachetools-5.5.0-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: packaging<25 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny==2.19.0->mlflow) (21.3)
# Collecting databricks-sdk<1,>=0.20.0
#   Using cached databricks_sdk-0.40.0-py3-none-any.whl (629 kB)
# Requirement already satisfied: typing-extensions>=4 in /databricks/python3/lib/python3.9/site-packages (from alembic!=1.10.0,<2->mlflow) (4.1.1)
# Collecting Mako
#   Using cached Mako-1.3.8-py3-none-any.whl (78 kB)
# Collecting google-auth~=2.0
#   Using cached google_auth-2.37.0-py2.py3-none-any.whl (209 kB)
# Collecting requests<3,>=2.17.3
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /databricks/python3/lib/python3.9/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.9)
# Collecting blinker>=1.9
#   Using cached blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Collecting Jinja2<4,>=2.11
#   Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Collecting Werkzeug>=3.1
#   Using cached werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Collecting itsdangerous>=2.2
#   Using cached itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Collecting click<9,>=7.0
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting gitdb<5,>=4.0.1
#   Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Collecting smmap<6,>=3.0.1
#   Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# Collecting rsa<5,>=3.1.4
#   Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Collecting pyasn1-modules>=0.2.1
#   Using cached pyasn1_modules-0.4.1-py3-none-any.whl (181 kB)
# Collecting typing-extensions>=4
#   Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /databricks/python3/lib/python3.9/site-packages (from graphene<4->mlflow) (2.8.2)
# Collecting graphql-core<3.3,>=3.1
#   Using cached graphql_core-3.2.5-py3-none-any.whl (203 kB)
# Collecting graphql-relay<3.3,>=3.1
#   Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Collecting zipp>=3.20
#   Using cached zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.9/site-packages (from Jinja2<4,>=2.11->mlflow) (2.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib<4->mlflow) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.9/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.9/site-packages (from matplotlib<4->mlflow) (1.3.2)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib<4->mlflow) (9.0.1)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.9/site-packages (from matplotlib<4->mlflow) (4.25.0)
# Collecting deprecated>=1.2.6
#   Using cached Deprecated-1.2.15-py2.py3-none-any.whl (9.9 kB)
# Collecting wrapt<2,>=1.10
#   Using cached wrapt-1.17.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (82 kB)
# Collecting opentelemetry-semantic-conventions==0.50b0
#   Using cached opentelemetry_semantic_conventions-0.50b0-py3-none-any.whl (166 kB)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.9/site-packages (from pandas<3->mlflow) (2021.3)
# Collecting pyasn1<0.7.0,>=0.4.6
#   Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Requirement already satisfied: six>=1.5 in /databricks/python3/lib/python3.9/site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.16.0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (2021.10.8)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /databricks/python3/lib/python3.9/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.19.0->mlflow) (2.0.4)
# Requirement already satisfied: joblib>=0.11 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Collecting greenlet!=0.4.17
#   Using cached greenlet-3.1.1-cp39-cp39-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (597 kB)
# Collecting MarkupSafe>=2.0
#   Using cached MarkupSafe-3.0.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (20 kB)
# Installing collected packages: zipp, wrapt, pyasn1, importlib-metadata, deprecated, typing-extensions, smmap, rsa, pyasn1-modules, opentelemetry-api, cachetools, requests, opentelemetry-semantic-conventions, MarkupSafe, greenlet, graphql-core, google-auth, gitdb, Werkzeug, sqlparse, sqlalchemy, pyyaml, opentelemetry-sdk, Mako, Jinja2, itsdangerous, graphql-relay, gitpython, databricks-sdk, cloudpickle, click, blinker, mlflow-skinny, markdown, gunicorn, graphene, Flask, docker, alembic, mlflow
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Not uninstalling typing-extensions at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be
#     Can't uninstall 'typing-extensions'. No files were found to uninstall.
#   Attempting uninstall: requests
#     Found existing installation: requests 2.27.1
#     Not uninstalling requests at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be
#     Can't uninstall 'requests'. No files were found to uninstall.
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 2.0.1
#     Not uninstalling markupsafe at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be
#     Can't uninstall 'MarkupSafe'. No files were found to uninstall.
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Not uninstalling jinja2 at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be
#     Can't uninstall 'Jinja2'. No files were found to uninstall.
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Not uninstalling click at /databricks/python3/lib/python3.9/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be
#     Can't uninstall 'click'. No files were found to uninstall.
# Successfully installed Flask-3.1.0 Jinja2-3.1.5 Mako-1.3.8 MarkupSafe-3.0.2 Werkzeug-3.1.3 alembic-1.14.0 blinker-1.9.0 cachetools-5.5.0 click-8.1.8 cloudpickle-3.1.0 databricks-sdk-0.40.0 deprecated-1.2.15 docker-7.1.0 gitdb-4.0.12 gitpython-3.1.44 google-auth-2.37.0 graphene-3.4.3 graphql-core-3.2.5 graphql-relay-3.2.0 greenlet-3.1.1 gunicorn-23.0.0 importlib-metadata-8.5.0 itsdangerous-2.2.0 markdown-3.7 mlflow-2.19.0 mlflow-skinny-2.19.0 opentelemetry-api-1.29.0 opentelemetry-sdk-1.29.0 opentelemetry-semantic-conventions-0.50b0 pyasn1-0.6.1 pyasn1-modules-0.4.1 pyyaml-6.0.2 requests-2.32.3 rsa-4.9 smmap-5.0.2 sqlalchemy-2.0.37 sqlparse-0.5.3 typing-extensions-4.12.2 wrapt-1.17.1 zipp-3.21.0
# Python interpreter will be restarted.
# Python interpreter will be restarted.
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_c9c19efe0c8740bda6359df9bd219f18/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_c9c19efe0c8740bda6359df9bd219f18/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-m4ctu11k
#          cwd: /tmp/pip-install-048ho9vb/sklearn_c9c19efe0c8740bda6359df9bd219f18/
#     Complete output (15 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/1c/395a83ee7b2d2ad7a05b453872053d41449564477c81dc356f720b16eac4/sklearn-0.0.post12.tar.gz#sha256=54cff9e20839b7b202321178228af4d9388bedf78425d9299fd9ee170d68802e (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post11.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_bab5a1cd403d444fabd470032c4b0d73/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_bab5a1cd403d444fabd470032c4b0d73/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-usgy3gbg
#          cwd: /tmp/pip-install-048ho9vb/sklearn_bab5a1cd403d444fabd470032c4b0d73/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a4/0b/d1c703256cf293be77b7db44dbef62251fe02a97d0bef981f7120b0b0c0f/sklearn-0.0.post11.tar.gz#sha256=af035c4f0b970b7fc2d3856079aa1aa1032df3d7f65048a9d87114abf13c4629 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post10.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_b2e2d23d6a7d4fe0ac9aae1b84ff68b5/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_b2e2d23d6a7d4fe0ac9aae1b84ff68b5/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-e12pnz27
#          cwd: /tmp/pip-install-048ho9vb/sklearn_b2e2d23d6a7d4fe0ac9aae1b84ff68b5/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/0e/b2a4cfaa9e12b9ca4c71507bc26d2c99d75de172c0088c9835a98cf146ff/sklearn-0.0.post10.tar.gz#sha256=d4cd5a2e64b3caaf82cd5e33c46884dfeec5ebf991710d9faeb4fe81cadb3ba6 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post9.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_1f0d0c5a2ebc4e93978b71d8df2d9cad/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_1f0d0c5a2ebc4e93978b71d8df2d9cad/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-b_2w4fjx
#          cwd: /tmp/pip-install-048ho9vb/sklearn_1f0d0c5a2ebc4e93978b71d8df2d9cad/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/28/86/207a003339023247fef1bb5bc9f5093140d17294b2f6d15bfcd4885e469e/sklearn-0.0.post9.tar.gz#sha256=1ff5864cf30489ee48a014fe8f4320d7bb59592392a4ef52ae9d7a37942615ac (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post7.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_d7f9ad0365074c8dad8e4edb98f6bd47/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_d7f9ad0365074c8dad8e4edb98f6bd47/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-yie7tfsy
#          cwd: /tmp/pip-install-048ho9vb/sklearn_d7f9ad0365074c8dad8e4edb98f6bd47/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/70/ce/81aa643f3c43488c4a1e417e45f696a61e7ac82b57190fad3c310df2c07b/sklearn-0.0.post7.tar.gz#sha256=1c89020b364fdc3aa2839e0ae34e8f0b406669e4b5c2359dda3ac398f9c76874 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post5.tar.gz (3.7 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_701bd9fbc04f4875852dac00cb18e04a/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_701bd9fbc04f4875852dac00cb18e04a/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-hi0hmk_q
#          cwd: /tmp/pip-install-048ho9vb/sklearn_701bd9fbc04f4875852dac00cb18e04a/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7a/93/e0e1b1e98f39dfca7ec9795cb46f6e09e88a2fd5d4a28e4b3d1f618a2aec/sklearn-0.0.post5.tar.gz#sha256=7377c714a03a79bbe9196f435db931fd2a6fa8c68514da7ed3a251fd08c52e2c (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post4.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_289bc2ac9b11407ca8a2aa80a4d5e6c2/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_289bc2ac9b11407ca8a2aa80a4d5e6c2/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-o59qgxxz
#          cwd: /tmp/pip-install-048ho9vb/sklearn_289bc2ac9b11407ca8a2aa80a4d5e6c2/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/99/b2/165110013aa66fae6fc13918ad0e9de4801e5f1691d371bf8b63328037e6/sklearn-0.0.post4.tar.gz#sha256=0e81ec9c32d4bb418e7be8f1ec1027d174975502dc84cbc4f4564b4cba31e674 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0.post1.tar.gz (3.6 kB)
#     ERROR: Command errored out with exit status 1:
#      command: /local_disk0/.ephemeral_nfs/envs/pythonEnv-73e8fe9b-2293-4bd7-9d22-87dc660169be/bin/python -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-048ho9vb/sklearn_d54b905ad4db4ceb9e8def410722b0b4/setup.py'"'"'; __file__='"'"'/tmp/pip-install-048ho9vb/sklearn_d54b905ad4db4ceb9e8def410722b0b4/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base /tmp/pip-pip-egg-info-c0xpgbc2
#          cwd: /tmp/pip-install-048ho9vb/sklearn_d54b905ad4db4ceb9e8def410722b0b4/
#     Complete output (18 lines):
#     The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#     rather than 'sklearn' for pip commands.
#
#     Here is how to fix this error in the main use cases:
#     - use 'pip install scikit-learn' rather than 'pip install sklearn'
#     - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#       (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#     - if the 'sklearn' package is used by one of your dependencies,
#       it would be great if you take some time to track which package uses
#       'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#     - as a last resort, set the environment variable
#       SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#     More information is available at
#     https://github.com/scikit-learn/sklearn-pypi-package
#
#     If the previous advice does not cover your use case, feel free to report it at
#     https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/db/1e/af4e9cded5093a92e60d4ae7149a02c7427661b2db66c8ea4d34b17864a2/sklearn-0.0.post1.tar.gz#sha256=76b9ed1623775168657b86b5fe966d45752e5c87f528de6240c38923b94147c5 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Using cached sklearn-0.0-py2.py3-none-any.whl
# Requirement already satisfied: scikit-learn in /databricks/python3/lib/python3.9/site-packages (from sklearn) (1.0.2)
# Requirement already satisfied: joblib>=0.11 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.1.1)
# Requirement already satisfied: numpy>=1.14.6 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.21.5)
# Requirement already satisfied: scipy>=1.1.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->sklearn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from scikit-learn->sklearn) (2.2.0)
# Installing collected packages: sklearn
# Successfully installed sklearn-0.0
# Python interpreter will be restarted.

# %%
import mlflow
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes
from sklearn.ensemble import RandomForestRegressor

# set the experiment id
mlflow.set_experiment(experiment_id="2214063680159067")

mlflow.autolog()
db = load_diabetes()

X_train, X_test, y_train, y_test = train_test_split(db.data, db.target)

# Create and train models.
rf = RandomForestRegressor(n_estimators=100, max_depth=6, max_features=3)
rf.fit(X_train, y_train)

# Use the model to make predictions on the test dataset.
predictions = rf.predict(X_test)
# Out:
# 2025/01/13 15:39:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for sklearn.
# 2025/01/13 15:39:31 WARNING mlflow.spark: With Pyspark >= 3.2, PYSPARK_PIN_THREAD environment variable must be set to false for Spark datasource autologging to work.
# 2025/01/13 15:39:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for pyspark.
# 2025/01/13 15:39:31 INFO mlflow.tracking.fluent: Autologging successfully enabled for pyspark.ml.
# 2025/01/13 15:39:31 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID 'a328d7198fdf43cb98b84aed3658c986', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2025/01/13 15:39:35 WARNING mlflow.utils.environment: Encountered an unexpected error while inferring pip requirements (model URI: /local_disk0/repl_tmp_data/ReplId-1b778-b4eb8-d7366-4/tmp106tgdaz/model/model.pkl, flavor: sklearn). Fall back to return ['scikit-learn==1.0.2', 'cloudpickle==3.1.0']. Set logging level to DEBUG to see the full traceback.
# 🏃 View run adorable-mule-518 at: https://community.cloud.databricks.com/ml/experiments/2214063680159067/runs/a328d7198fdf43cb98b84aed3658c986
# 🧪 View experiment at: https://community.cloud.databricks.com/ml/experiments/2214063680159067
